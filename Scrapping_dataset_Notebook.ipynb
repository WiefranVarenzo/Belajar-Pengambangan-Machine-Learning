# %% [markdown]
# **Pengenalan Dataset**
#
# 1. **Sumber Dataset**:
#    Dataset bersumber dari hasil Scrapping ulasan di aplikasi Google Play Store, dimana ulasan yang diambil adalah ulasan dari aplikasi M-banking BCA
#
# 2. **Kriteria Dataset**:
#    - **Jumlah Baris**: Minimal 144000 baris untuk memastikan dataset cukup besar untuk analisis yang bermakna.
#    - **Tipe Data**: Harus mengandung data **kategorikal** dan **numerikal**.
#      - *Kategorikal*: reviewId, Username, userImage, content, reviewCreatedVersion, replyContent, dan AppVersion
#      - *Numerikal*: Misalnya thumbsUpCount, score.

# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.5 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %%
from google_play_scraper import app, reviews, Sort, reviews_all
import pandas as pd
from google_play_scraper import app, reviews_all, Sort

# %%
scrapreview = reviews_all(
    'com.bca',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=150000
)

import csv

with open('ulasan_aplikasi.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Review'])
    for review in scrapreview:
        writer.writerow([review['content']])  #

# %%
app_reviews_df = pd.DataFrame(scrapreview)
app_reviews_df.shape
app_reviews_df.head()
app_reviews_df.to_csv('ulasan_aplikasi.csv', index=False)

# Membuat DataFrame dari hasil scrapreview
app_reviews_df = pd.DataFrame(scrapreview)

# Menghitung jumlah baris dan kolom dalam DataFrame
jumlah_ulasan, jumlah_kolom = app_reviews_df.shape

# %%
app_reviews_df
# Out:
#                                     reviewId         userName  \
# 0       73e00a87-fef3-4680-afa6-ab7daef9fd80  Pengguna Google
# 1       9769cfd6-6fad-4795-9d1a-029e0ce5460c  Pengguna Google
# 2       471db5f2-8dc4-4d12-968c-8e8be99c1997  Pengguna Google
# 3       f07788fd-b7bc-418b-ba92-ab7a30f1ba0f  Pengguna Google
# 4       ea3f9054-6a88-48ed-bb3a-0a76465c2f7a  Pengguna Google
# ...                                      ...              ...
# 143995  a2e74fc6-cdbc-4666-9c8c-0a1973faeec9  Pengguna Google
# 143996  6495f392-ddec-4c60-809f-259ed066c8ec  Pengguna Google
# 143997  fe194723-25ca-403a-bcb5-876fbe892d7f  Pengguna Google
# 143998  5fc05cb1-d44b-4ce1-9426-1f43d38250a4  Pengguna Google
# 143999  bf6890c6-3068-4c73-b0d1-63187d7a9a0e  Pengguna Google
#
#                                                 userImage  \
# 0       https://play-lh.googleusercontent.com/EGemoI2N...
# 1       https://play-lh.googleusercontent.com/EGemoI2N...
# 2       https://play-lh.googleusercontent.com/EGemoI2N...
# 3       https://play-lh.googleusercontent.com/EGemoI2N...
# 4       https://play-lh.googleusercontent.com/EGemoI2N...
# ...                                                   ...
# 143995  https://play-lh.googleusercontent.com/EGemoI2N...
# 143996  https://play-lh.googleusercontent.com/EGemoI2N...
# 143997  https://play-lh.googleusercontent.com/EGemoI2N...
# 143998  https://play-lh.googleusercontent.com/EGemoI2N...
# 143999  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                   content  score  \
# 0       apknya udah bagus, tapi menurutku ada beberapa...      4
# 1       Di Update minta verifikasi ulang gagal terus, ...      1
# 2       Sudah lama pake aplikasi ini Alhamdulillah san...      3
# 3       Untuk aplikasi berjalan sangat baik dan mudah ...      5
# 4       Astaga.. ribet banget.. baru pertama kali inst...      1
# ...                                                   ...    ...
# 143995                                    Sangat membantu      5
# 143996                                    Sangat membantu      5
# 143997           Sayang bnget,malu2in Bca aja...PARAHHHHH      1
# 143998                         Keren mempermudah buwat TF      5
# 143999                                    sangat membantu      1
#
#         thumbsUpCount reviewCreatedVersion                  at  \
# 0                   4                4.6.1 2025-03-21 12:01:42
# 1                  42                4.6.1 2025-03-24 07:04:37
# 2                   8                4.6.0 2025-03-18 03:04:46
# 3                 254                4.5.7 2025-02-11 11:35:21
# 4                 244                4.5.9 2025-03-02 23:00:44
# ...               ...                  ...                 ...
# 143995              0                4.2.6 2024-05-27 09:12:10
# 143996              0                2.2.4 2019-11-14 12:46:44
# 143997              0                 None 2020-05-21 20:53:35
# 143998              0                 None 2022-08-23 19:08:46
# 143999              0                1.8.0 2019-02-28 08:33:40
#
#                                              replyContent           repliedAt  \
# 0       Mohon maaf atas ketidaknyamanannya. Saran dan ... 2025-03-21 12:11:52
# 1       Mohon maaf atas ketidaknyamanan Bapak/Ibu, unt... 2025-03-24 07:28:43
# 2       Mohon maaf atas kendala yang Bapak/Ibu alami. ... 2025-03-18 03:39:05
# 3       Mohon maaf atas ketidaknyamanannya. Apabila la... 2025-02-11 12:03:17
# 4       Mohon maaf atas kendala yang Bapak/Ibu alami, ... 2025-03-03 01:35:52
# ...                                                   ...                 ...
# 143995  Terima kasih atas ulasannya. Semoga aplikasi B... 2024-05-27 09:41:45
# 143996  Terima kasih atas ulasannya. Semoga fasilitas ... 2019-11-18 05:28:26
# 143997                                               None                 NaT
# 143998  Terima kasih atas ulasannya. Semoga aplikasi B... 2022-08-26 18:27:37
# 143999  Terima kasih atas ulasannya. Semoga fasilitas ... 2019-03-01 08:48:21
#
#        appVersion
# 0           4.6.1
# 1           4.6.1
# 2           4.6.0
# 3           4.5.7
# 4           4.5.9
# ...           ...
# 143995      4.2.6
# 143996      2.2.4
# 143997       None
# 143998       None
# 143999      1.8.0
#
# [144000 rows x 11 columns]

# %%
app_reviews_df.shape
# Out:
# (144000, 11)

# %%
app_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144000 entries, 0 to 143999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   reviewId              144000 non-null  object
#  1   userName              144000 non-null  object
#  2   userImage             144000 non-null  object
#  3   content               144000 non-null  object
#  4   score                 144000 non-null  int64
#  5   thumbsUpCount         144000 non-null  int64
#  6   reviewCreatedVersion  117964 non-null  object
#  7   at                    144000 non-null  datetime64[ns]
#  8   replyContent          137563 non-null  object
#  9   repliedAt             137563 non-null  datetime64[ns]
#  10  appVersion            117964 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 12.1+ MB

# %%
selected_columns = ['content', 'score', 'thumbsUpCount', 'reviewCreatedVersion']
df_selected = app_reviews_df[selected_columns]

# %%
print(df_selected.head())
df_selected.to_csv('data_ulasan.csv', index=False)
# Out:
#                                              content  score  thumbsUpCount  \
# 0  apknya udah bagus, tapi menurutku ada beberapa...      4              4
# 1  Di Update minta verifikasi ulang gagal terus, ...      1             42
# 2  Sudah lama pake aplikasi ini Alhamdulillah san...      3              8
# 3  Untuk aplikasi berjalan sangat baik dan mudah ...      5            254
# 4  Astaga.. ribet banget.. baru pertama kali inst...      1            244
#
#   reviewCreatedVersion
# 0                4.6.1
# 1                4.6.1
# 2                4.6.0
# 3                4.5.7
# 4                4.5.9
